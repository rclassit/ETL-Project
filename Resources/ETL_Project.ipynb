# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Export Json Files - Json_Award Clean Up

# %%
#Import Json File for Json_Awards and Clean up/Normalize Data 
import json
json_file = "../Resources/json_award.json"
with open(json_file, 'r') as f:
    data = json.loads(f.read())
df =  pd.json_normalize(data)
df["laureates"] = df["laureates"].str[0]
df["laureates"].apply(pd.Series)
#Note id, award year, prize amount, prize amount adjusted, category, are all important categories in this dataset.  
#I think we should likely focus on these and drop "known name" since that's what were using to join from our other table
df = pd.concat([df.drop(["laureates"],axis=1),df["laureates"].apply(pd.Series)],axis=1)
df.head()
# Out:
#   awardYear  prizeAmount  prizeAmountAdjusted             category.en  \
# 0      1901       150782              8567159               Chemistry
# 1      1901       150782              8567159              Literature
# 2      1901       150782              8567159                   Peace
# 3      1901       150782              8567159                 Physics
# 4      1901       150782              8567159  Physiology or Medicine
#
#                category.no              category.se  \
# 0                    Kjemi                     Kemi
# 1               Litteratur               Litteratur
# 2                     Fred                     Fred
# 3                   Fysikk                    Fysik
# 4  Fysiologi eller medisin  Fysiologi eller medicin
#
#                          categoryFullName.en  \
# 0               The Nobel Prize in Chemistry
# 1             The Nobel Prize in  Literature
# 2                      The Nobel Peace Prize
# ...

# %% [markdown]
# ## Export Json_Laureates

# %%
json_file = "../Resources/json_laureates.json"
df = pd.read_json(json_file)
df
#This is tricky, trying to take columns relevant to the Laureate's name but running into same isssue with above.
#normalizing the data brings out a table similar to above.  
df1 = df[['id','knownName','gender','birth','orgName','founded']]
df1 = pd.json_normalize(df1)
# Want to just normalize the data above ^ without the additional columns
# Out:
#       id                                          knownName gender  \
# 0    745  {'en': 'A. Michael Spence', 'se': 'A. Michael ...   male
# 1    102       {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'}   male
# 2    779  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...   male
# 3    259           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}   male
# 4    114         {'en': 'Abdus Salam', 'se': 'Abdus Salam'}   male
# ..   ...                                                ...    ...
# 938  826   {'en': 'Yoichiro Nambu', 'se': 'Yoichiro Nambu'}   male
# 939  927  {'en': 'Yoshinori Ohsumi', 'se': 'Yoshinori Oh...   male
# 940  265         {'en': 'Yuan T. Lee', 'se': 'Yuan T. Lee'}   male
# 941  794       {'en': 'Yves Chauvin', 'se': 'Yves Chauvin'}   male
# 942  726   {'en': 'Zhores Alferov', 'se': 'Zhores Alferov'}   male
#
#                                                  birth orgName founded
# 0    {'date': '1943-00-00', 'place': {'city': {'en'...     NaN     NaN
# ...
